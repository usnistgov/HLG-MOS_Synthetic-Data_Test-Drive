# %% [markdown]
# # satgpa synthesis with CART - RSynthpop
# From the quickstart doc: https://docs.google.com/document/d/1glRt4q-0tFi_LlOioY42V_mS-h0JuYRjtE736N0Fua4/edit#heading=h.d0u368ia5ili

# %%
# %load_ext rpy2.ipython

# %%
# %%R
# install.packages(c('synthpop','GGally'))
# Out:
# R[write to console]: Installing packages into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# R[write to console]: trying URL 'https://cran.rstudio.com/src/contrib/synthpop_1.7-0.tar.gz'
#
# R[write to console]: Content type 'application/x-gzip'
# R[write to console]:  length 1198774 bytes (1.1 MB)
#
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# R[write to console]: =
# ...

# %%
# %%R
# library(synthpop)
# library(GGally)
# satgpa = read.csv("https://www.openintro.org/data/csv/satgpa.csv")
#
# codebook.syn(satgpa)
# mydata <- satgpa[,c(1,2,3,5,6)]
# Out:
# R[write to console]: Find out more at https://www.synthpop.org.uk/
#
# R[write to console]: Loading required package: ggplot2
#
# R[write to console]: Registered S3 method overwritten by 'GGally':
#   method from
#   +.gg   ggplot2

# %% [markdown]
# # Generate synthetic data

# %%
# %%R
# #generate synthetic data with default parameters
# synthetic_dataset <-syn(satgpa, minnumlevels = 2)
# Out:
# ...
# Consider changing them to factors. You can do it using parameter 'minnumlevels'.
#
# Synthesis
# -----------
#  sex sat_v sat_m hs_gpa fy_gpa
#
# Variable(s): sex numeric but with only 2 or fewer distinct values turned into factor(s) for synthesis.
#
# Synthesis
# -----------
#  sex sat_v sat_m sat_sum hs_gpa fy_gpa

# %% [markdown]
# # Calculate privacy
# from: https://docs.google.com/document/d/1fYZeBvnrmvOTKIgc9az6fbdG4PprJG7qvS96zWrp9NI/edit

# %%
# %%R
#
#
# replicated.uniques(synthetic_dataset, satgpa)
# Out:
# $replications
#    [1] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [13] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [25] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [37] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE
#   [49] FALSE FALSE FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE
#   [61] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [73] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [85] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#   [97] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE  TRUE
#  [109] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [121] FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
#  [133] FALSE FALSE FALSE FALSE  TRUE FALSE FALSE FALSE FALSE FALSE FALSE FALSE
# ...

# %% [markdown]
# # Evaluate utility of synthesis
# from: https://docs.google.com/document/d/1U9G5FYxIsvuW_JGQ84Rk7N5aajvFy3tDtz5VvzSR1Ak/edit

# %%
# %%R
# utility.gen(synthetic_dataset,satgpa)
#
# utility.tables(synthetic_dataset, satgpa)
# Out:
# Running 50 permutations to get NULL utilities and printing every 10th.
# synthesis 1   10 20 30 40 50
# Two-way utility: S_pMSE value plotted for 15 pairs of variables.
#
# Variable combinations with worst 5 utility scores (S_pMSE):
#   2.sat_v:5.hs_gpa   2.sat_v:6.fy_gpa 4.sat_sum:5.hs_gpa  3.sat_m:4.sat_sum
#             1.8719             1.8364             1.5017             1.4251
#      1.sex:2.sat_v
#             1.4232
#
# Medians and maxima of selected utility measures for all tables compared
#        Medians  Maxima
# pMSE    0.0013  0.0028
# S_pMSE  1.1089  1.8719
# df     24.0000 24.0000
#
# For more details of all scores use print.tabs = TRUE.

# %%
# %%R
# multi.compare(synthetic_dataset, satgpa, var = "sat_v", by = "sex")
# Out:
# Plots of  sat_v  by  sex
# Numbers in each plot (observed data):
#
# sex
#   1   2
# 516 484
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# multi.compare(synthetic_dataset, satgpa, var = "sat_m", by = "sex")
# Out:
# Plots of  sat_m  by  sex
# Numbers in each plot (observed data):
#
# sex
#   1   2
# 516 484
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# multi.compare(synthetic_dataset, satgpa, var = "hs_gpa", by = "sex")
# Out:
# Plots of  hs_gpa  by  sex
# Numbers in each plot (observed data):
#
# sex
#   1   2
# 516 484
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# multi.compare(synthetic_dataset, satgpa, var = "fy_gpa", by = "sex")
# Out:
# Plots of  fy_gpa  by  sex
# Numbers in each plot (observed data):
#
# sex
#   1   2
# 516 484
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %%
# %%R
# multi.compare(synthetic_dataset, satgpa, var = "sat_m", by="sex", cont.type = "boxplot")
# Out:
# Plots of  sat_m  by  sex
# Numbers in each plot (observed data):
#
# sex
#   1   2
# 516 484

# %%
# %%R
# #try pair plot
# orig = satgpa
# orig['Source'] = "Original"
# syn = synthetic_dataset$syn
# syn["Source"] = 'Synthetic'
#
# df = rbind(orig,syn)
# df$sex = as.factor(df$sex)
# df$Source = as.factor(df$Source)
# ggpairs(df,columns=1:(ncol(df)-1),mapping=ggplot2::aes(color=Source,alpha=0.01))
# Out:
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
#
# R[write to console]: `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.

# %% [markdown]
# # Evaluate Testing Analysis Utility
# Train a ML model on original data one feature at a time, and score predictions on withheld original data.  Repeat for synthetic data.  Does the test performance hold?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import lightgbm as lgb
df = %R df

# %%
df
# Out:
#      sex  sat_v  sat_m  sat_sum  hs_gpa  fy_gpa     Source
# 1      1   65.0   62.0    127.0    3.40    3.18   Original
# 2      2   58.0   64.0    122.0    4.00    3.33   Original
# 3      2   56.0   60.0    116.0    3.75    3.25   Original
# 4      1   42.0   53.0     95.0    3.75    2.42   Original
# 5      1   55.0   52.0    107.0    4.00    2.63   Original
# ...   ..    ...    ...      ...     ...     ...        ...
# 1996   1   54.0   66.0    120.0    3.75    2.60  Synthetic
# 1997   1   69.0   69.0    141.0    3.50    2.31  Synthetic
# 1998   2   37.0   38.0     78.0    2.80    2.04  Synthetic
# 1999   2   49.0   61.0    111.0    3.30    2.47  Synthetic
# 2000   1   45.0   66.0    111.0    2.50    2.21  Synthetic
#
# [2000 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split

# for original data (in):
Xtrain_in,Xtest_in = train_test_split(df.loc[df.Source=='Original'].drop(columns='Source'),train_size=0.5)

orig_scores =[]
for col in Xtest_in.columns:
  model_in = lgb.LGBMRegressor().fit(Xtrain_in.drop(columns = col),Xtrain_in[col]) # make regression model for each column
  orig_scores.append({'Source':'Original','Column':col,'Score':model_in.score(Xtest_in.drop(columns=col), Xtest_in[col])})

# for synthetic data (out):
syn_scores = []
Xtrain_out,Xtest_out = train_test_split(df.loc[df.Source=='Synthetic'].drop(columns='Source'),train_size=0.5)

for col in Xtest_out.columns:
  model_out = lgb.LGBMRegressor().fit(Xtrain_out.drop(columns = col),Xtrain_out[col]) # make regression model for each column
  syn_scores.append({'Source':'Synthetic','Column':col,'Score':model_out.score(Xtest_out.drop(columns=col), Xtest_out[col])})

# %%
df_compare = pd.pivot_table(pd.concat([pd.DataFrame(orig_scores),pd.DataFrame(syn_scores)]),values='Score',index='Column',columns='Source')
df_compare.plot('Original','Synthetic',kind='scatter')
plt.plot([0,1],[0,1],'k--')
plt.xlabel('R2 for model trained on Original')
plt.ylabel('R2 for model trained on Synthetic')
# Out:
# Text(0, 0.5, 'R2 for model trained on Synthetic')

# %%
df_compare
# Out:
# Source   Original  Synthetic
# Column
# fy_gpa   0.228438   0.232584
# hs_gpa   0.199023   0.226497
# sat_m    0.949608   0.935000
# sat_sum  0.986352   0.976137
# sat_v    0.951150   0.918150
# sex     -0.118437   0.060447

# %% [markdown]
# The synthetic data preserves many of the predictive relationships in the data set.  This isnt so surprising, CART and LightGBM are somewhat related.  For features that are a noiseless function of other features like `sat_sum` there is still a significant difference between synthetic and original data, where the correlation shows extra noise:

# %%
df_sums_check = df

# %%
df_sums_check['Sum'] = df_sums_check['sat_v']+df_sums_check['sat_m']

# %%
df_sums_check.groupby('Source').plot('sat_sum','Sum',kind='scatter')
# Out:
# Source
# Original     AxesSubplot(0.125,0.125;0.775x0.755)
# Synthetic    AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object
